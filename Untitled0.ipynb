# %%
from google.colab import drive

# 구글 드라이브 마운트
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
# CSV 파일 경로
file_path = '/content/drive/MyDrive/Capstone/서울특별시 공공자전거 이용정보(일별)_2306.csv'

# %%
# 대여소 번호 목록
target_station_numbers = [
    1199, 1200, 1201, 1203, 1204, 1205, 1206, 1207, 1208, 1209,
    1210, 1211, 1212, 1213, 1214, 1215, 1217, 1218, 1220, 1221, 1222,
    1224, 1226, 1227, 1228, 1229, 1230, 1231, 1232, 1233, 1235, 1239,
    1240, 1241, 1242, 1243, 1244, 1245, 1246, 1247, 1248, 1249, 1250,
    1251, 1253, 1256, 1257, 1258, 1259, 1260, 1262, 1263, 1264, 1265,
    1266, 1267, 1268, 1269, 1271, 1274, 1275, 1277, 1278, 1279, 1280,
    1282, 1283, 1285, 1286, 1287, 1288, 1289, 1290, 1291, 1293, 1295,
    1296, 1297, 2549, 2550, 2601, 2603, 2604, 2605, 2606, 2608, 2609,
    2610, 2611, 2612, 2613, 2614, 2615, 2616, 2617, 2618, 2619, 2620, 2621,
    2622, 2623, 2625, 2626, 2627, 2628, 2630, 2631, 2632, 2633, 2634, 2635,
    2637, 2638, 2639, 2641, 2642, 2643, 2644, 2645, 2646, 2647, 2648, 2649,
    2650, 2651, 2652, 2653, 2654, 2655, 2656, 2657, 4414, 4415, 4452,
    4453, 4454, 4456, 4457, 4458, 4460, 4461, 4462, 4463, 4464, 4465,
    4467, 4468, 4469, 4472, 4473, 4474, 4475, 4478, 4479, 4480, 4481,
    4483, 4484, 4485, 4486, 4488, 4490, 4491, 4493, 4496, 4497, 4834,
    4835, 4852, 4853, 4854, 4855, 4856, 4857, 4859, 4860, 4861, 4862, 4863,
    4864, 4865, 4867, 4868, 4869, 4870, 4871, 4872, 4873, 4874, 4875, 4876,
    4879, 4880, 4881, 4882, 4883, 4884, 4885, 4886, 4887, 4888, 4889, 4891,
    4892, 4893, 4894, 4895
]

# CSV 파일을 데이터프레임으로 읽기
df = pd.read_csv(file_path, encoding='cp949')

# "대여소 번호"가 목록에 있는 행만 선택
filtered_df = df[df['대여소번호'].isin(target_station_numbers)]

# 결과 출력
print(filtered_df)
# Out:
#                대여일자  대여소번호                    대여소 대여구분코드   성별   연령대   이용건수  \
# 11       2023-06-01   1260    1260. 방이동 한양3차아파트 옆    정기권  NaN  ~10대      1
# 12       2023-06-01   1271            1271. 송파도서관    정기권  NaN  ~10대      1
# 52       2023-06-01   1282  1282. 송파소방서 맞은편(성내4교)    정기권  NaN  ~10대      1
# 65       2023-06-01   1291       1291. 서울체육고등학교 앞    정기권  NaN  ~10대      2
# 77       2023-06-01   2622      2622. 올림픽공원역 3번출구    정기권  NaN  ~10대      1
# ...             ...    ...                    ...    ...  ...   ...    ...
# 2258414  2023-06-30   1244         1244. 문정 법조단지8    정기권    M    기타      2
# 2258415  2023-06-30   1244         1244. 문정 법조단지8    정기권    M    기타      2
# 2258416  2023-06-30   1246        1246. 문정 법조단지10    정기권    M    기타      1
# 2258417  2023-06-30   1248           1248. 방이초등학교    정기권    M    기타      1
# 2258445  2023-06-30   1250         1250.문정2동 주민센터    정기권    M    기타      1
#
#             운동량   탄소량   이동거리(M)  이용시간(분)
# ...

# %%
filtered_df.to_csv('/content/drive/MyDrive/Capstone/송파구 23_06.csv', index=False)

# %%
# !sudo apt-get install -y fonts-nanum
# !sudo fc-cache -fv
# !rm ~/.cache/matplotlib -rf
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following NEW packages will be installed:
#   fonts-nanum
# 0 upgraded, 1 newly installed, 0 to remove and 9 not upgraded.
# Need to get 10.3 MB of archives.
# After this operation, 34.1 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy/universe amd64 fonts-nanum all 20200506-1 [10.3 MB]
# Fetched 10.3 MB in 1s (7,933 kB/s)
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 78, <> line 1.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# dpkg-preconfigure: unable to re-open stdin:
# Selecting previously unselected package fonts-nanum.
# ...

# %%
import matplotlib.pyplot as plt

plt.rc('font', family='NanumBarunGothic')

# %%
import pandas as pd
# CSV 파일 경로
file_path = '/content/drive/MyDrive/Capstone/공공자전거 이용정보(일별)_2021.04.csv'

# %%
# 대여소 번호 목록
target_station_numbers = [
    1199, 1200, 1201, 1203, 1204, 1205, 1206, 1207, 1208, 1209,
    1210, 1211, 1212, 1213, 1214, 1215, 1217, 1218, 1220, 1221, 1222,
    1224, 1226, 1227, 1228, 1229, 1230, 1231, 1232, 1233, 1235, 1239,
    1240, 1241, 1242, 1243, 1244, 1245, 1246, 1247, 1248, 1249, 1250,
    1251, 1253, 1256, 1257, 1258, 1259, 1260, 1262, 1263, 1264, 1265,
    1266, 1267, 1268, 1269, 1271, 1274, 1275, 1277, 1278, 1279, 1280,
    1282, 1283, 1285, 1286, 1287, 1288, 1289, 1290, 1291, 1293, 1295,
    1296, 1297, 2549, 2550, 2601, 2603, 2604, 2605, 2606, 2608, 2609,
    2610, 2611, 2612, 2613, 2614, 2615, 2616, 2617, 2618, 2619, 2620, 2621,
    2622, 2623, 2625, 2626, 2627, 2628, 2630, 2631, 2632, 2633, 2634, 2635,
    2637, 2638, 2639, 2641, 2642, 2643, 2644, 2645, 2646, 2647, 2648, 2649,
    2650, 2651, 2652, 2653, 2654, 2655, 2656, 2657, 4414, 4415, 4452,
    4453, 4454, 4456, 4457, 4458, 4460, 4461, 4462, 4463, 4464, 4465,
    4467, 4468, 4469, 4472, 4473, 4474, 4475, 4478, 4479, 4480, 4481,
    4483, 4484, 4485, 4486, 4488, 4490, 4491, 4493, 4496, 4497, 4834,
    4835, 4852, 4853, 4854, 4855, 4856, 4857, 4859, 4860, 4861, 4862, 4863,
    4864, 4865, 4867, 4868, 4869, 4870, 4871, 4872, 4873, 4874, 4875, 4876,
    4879, 4880, 4881, 4882, 4883, 4884, 4885, 4886, 4887, 4888, 4889, 4891,
    4892, 4893, 4894, 4895
]

# CSV 파일을 데이터프레임으로 읽기
df = pd.read_csv(file_path, encoding='cp949')

# "대여소 번호"가 목록에 있는 행만 선택
filtered_df = df[df['대여소번호'].isin(target_station_numbers)]

# 결과 출력
print(filtered_df)
# Out:
#                대여일자  대여소번호                 대여소  대여구분코드  성별    연령대코드  이용건수  \
# 17362    2021-04-01   1199     1199. 우장산역 3번출구  일일(회원)  \N  AGE_001     1
# 17363    2021-04-01   1199     1199. 우장산역 3번출구  일일(회원)  \N  AGE_002     6
# 17364    2021-04-01   1199     1199. 우장산역 3번출구  일일(회원)  \N  AGE_003     1
# 17365    2021-04-01   1199     1199. 우장산역 3번출구  일일(회원)  \N  AGE_005     1
# 17366    2021-04-01   1199     1199. 우장산역 3번출구  일일(회원)   F  AGE_002     3
# ...             ...    ...                 ...     ...  ..      ...   ...
# 1033356  2021-04-29   2657  2657.송파 파인타운 11단지       정기   M  AGE_002     1
# 1033357  2021-04-29   2657  2657.송파 파인타운 11단지       정기   M  AGE_003     1
# 1033358  2021-04-29   2657  2657.송파 파인타운 11단지       정기   M  AGE_004     1
# 1033359  2021-04-29   2657  2657.송파 파인타운 11단지       정기   M  AGE_005     1
# 1033360  2021-04-29   2657  2657.송파 파인타운 11단지       정기   M  AGE_008     2
#
#             운동량   탄소량   이동거리(M)  이용시간(분)
# ...

# %%
print(df.columns)
# Out:
# Index(['´ë¿©ÀÏÀÚ', '´ë¿©¼Ò¹øÈ£', '´ë¿©¼Ò', '´ë¿©±¸ºÐÄÚµå', '¼ºº°', '¿¬·É´ë',
#        ' ÀÌ¿ë°Ç¼ö', '¿îµ¿·®', 'Åº¼Ò·®', 'ÀÌµ¿°Å¸®(M)', 'ÀÌ¿ë½Ã°£(ºÐ)'],
#       dtype='object')

# %%
filtered_df.to_csv('/content/drive/MyDrive/Capstone/송파구 21_04.csv', index=False)

# %%
import pandas as pd
# CSV 파일 경로
file_path = '/content/drive/MyDrive/Capstone/공공자전거 이용정보(일별)_2111.csv'

# %%
# 대여소 번호 목록
target_station_numbers = [
    1199, 1200, 1201, 1203, 1204, 1205, 1206, 1207, 1208, 1209,
    1210, 1211, 1212, 1213, 1214, 1215, 1217, 1218, 1220, 1221, 1222,
    1224, 1226, 1227, 1228, 1229, 1230, 1231, 1232, 1233, 1235, 1239,
    1240, 1241, 1242, 1243, 1244, 1245, 1246, 1247, 1248, 1249, 1250,
    1251, 1253, 1256, 1257, 1258, 1259, 1260, 1262, 1263, 1264, 1265,
    1266, 1267, 1268, 1269, 1271, 1274, 1275, 1277, 1278, 1279, 1280,
    1282, 1283, 1285, 1286, 1287, 1288, 1289, 1290, 1291, 1293, 1295,
    1296, 1297, 2549, 2550, 2601, 2603, 2604, 2605, 2606, 2608, 2609,
    2610, 2611, 2612, 2613, 2614, 2615, 2616, 2617, 2618, 2619, 2620, 2621,
    2622, 2623, 2625, 2626, 2627, 2628, 2630, 2631, 2632, 2633, 2634, 2635,
    2637, 2638, 2639, 2641, 2642, 2643, 2644, 2645, 2646, 2647, 2648, 2649,
    2650, 2651, 2652, 2653, 2654, 2655, 2656, 2657, 4414, 4415, 4452,
    4453, 4454, 4456, 4457, 4458, 4460, 4461, 4462, 4463, 4464, 4465,
    4467, 4468, 4469, 4472, 4473, 4474, 4475, 4478, 4479, 4480, 4481,
    4483, 4484, 4485, 4486, 4488, 4490, 4491, 4493, 4496, 4497, 4834,
    4835, 4852, 4853, 4854, 4855, 4856, 4857, 4859, 4860, 4861, 4862, 4863,
    4864, 4865, 4867, 4868, 4869, 4870, 4871, 4872, 4873, 4874, 4875, 4876,
    4879, 4880, 4881, 4882, 4883, 4884, 4885, 4886, 4887, 4888, 4889, 4891,
    4892, 4893, 4894, 4895
]

# CSV 파일을 데이터프레임으로 읽기
df = pd.read_csv(file_path, encoding='ISO-8859-1')

# "대여소 번호"가 목록에 있는 행만 선택
filtered_df = df[df['´ë¿©¼Ò¹øÈ£'].isin(target_station_numbers)]

# 결과 출력
print(filtered_df)
# Out:
#            ´ë¿©ÀÏÀÚ  ´ë¿©¼Ò¹øÈ£                           ´ë¿©¼Ò ´ë¿©±¸ºÐÄÚµå  \
# 17237    2021-11-01        1199           1199. ¿ìÀå»ê¿ª 3¹øÃâ±¸   ÀÏÀÏ(È¸¿ø)
# 17238    2021-11-01        1199           1199. ¿ìÀå»ê¿ª 3¹øÃâ±¸   ÀÏÀÏ(È¸¿ø)
# 17239    2021-11-01        1199           1199. ¿ìÀå»ê¿ª 3¹øÃâ±¸   ÀÏÀÏ(È¸¿ø)
# 17240    2021-11-01        1199           1199. ¿ìÀå»ê¿ª 3¹øÃâ±¸   ÀÏÀÏ(È¸¿ø)
# 17241    2021-11-01        1199           1199. ¿ìÀå»ê¿ª 3¹øÃâ±¸   ÀÏÀÏ(È¸¿ø)
# ...             ...         ...                              ...          ...
# 1159550  2021-11-30        4882  4882. À§·ÊÆ÷·¹»þÀÎ18´ÜÁö 1802µ¿         Á¤±â
# 1159551  2021-11-30        4882  4882. À§·ÊÆ÷·¹»þÀÎ18´ÜÁö 1802µ¿         Á¤±â
# 1159552  2021-11-30        4883  4883. À§·ÊÆ÷·¹»þÀÎ18´ÜÁö 1812µ¿   ÀÏÀÏ(È¸¿ø)
# 1159553  2021-11-30        4883  4883. À§·ÊÆ÷·¹»þÀÎ18´ÜÁö 1812µ¿         Á¤±â
# 1159554  2021-11-30        4883  4883. À§·ÊÆ÷·¹»þÀÎ18´ÜÁö 1812µ¿         Á¤±â
#
# ...

# %%
filtered_df.to_csv('/content/drive/MyDrive/Capstone/송파구 21_11.csv', index=False)
